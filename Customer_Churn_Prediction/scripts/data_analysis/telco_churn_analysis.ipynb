# %% [markdown]
# Dependancies

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Logic to analysis the dataset.

# %%
#load dataset 
telco_df = pd.read_csv('data/unprocessed_data/telco_customer_data_v2.csv')
